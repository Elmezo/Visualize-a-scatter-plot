# %% [markdown]
# #   Data Science tools and software

# %% [markdown]
# # Abdulrahman Alaa Eldeen Ezz Eldeen

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
import pandas as pd 
import numpy as np
from sklearn_extra.cluster import KMedoids
marker_colors = np.arange(start=0, stop=150, step=1)

# %%
iris = datasets.load_iris()
iris_df=pd.DataFrame(iris.data)
iris_df.columns=['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid']
iris_df.dropna(how="all", inplace=True)

iris_X=iris_df.iloc[:,[0,1,2,3]]

# %%
iris_X
# Out:
#      sepal_len  sepal_wid  petal_len  petal_wid
# 0          5.1        3.5        1.4        0.2
# 1          4.9        3.0        1.4        0.2
# 2          4.7        3.2        1.3        0.2
# 3          4.6        3.1        1.5        0.2
# 4          5.0        3.6        1.4        0.2
# ..         ...        ...        ...        ...
# 145        6.7        3.0        5.2        2.3
# 146        6.3        2.5        5.0        1.9
# 147        6.5        3.0        5.2        2.0
# 148        6.2        3.4        5.4        2.3
# 149        5.9        3.0        5.1        1.8
#
# [150 rows x 4 columns]

# %%
plt.scatter(iris_X['sepal_len'], iris_X['sepal_wid'],c=marker_colors, cmap='viridis')
plt.title("petal width vs petal length")
plt.xlabel('x label')
plt.ylabel('y label')
plt.show()

# %%
plt.scatter(iris_X['petal_len'], iris_X['petal_wid'],c=marker_colors, cmap='viridis')
plt.title("petal width vs petal length")
plt.xlabel('x label')
plt.ylabel('y label')
plt.show()

# %%
kmedoids = KMedoids(n_clusters=2,metric="cosine",init="random" ,random_state=0)
kmedoids.fit_predict(iris_X)
plt.scatter(iris_X['sepal_len'], iris_X['sepal_wid'],c=kmedoids.labels_,cmap='rainbow')

# %%
kmedoids = KMedoids(n_clusters=2,metric="cosine",init="random" ,random_state=0)
kmedoids.fit_predict(iris_X)
plt.scatter(iris_X['petal_len'], iris_X['petal_wid'],c=kmedoids.labels_,cmap='rainbow')

# %% [markdown]
# ## -------------------------------------------------------------------------------------------------------------------

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %%
def f(x, y):
    return np.cos(x*y*100)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 90)

# %%
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
fig = plt.figure(figsize=(20,10))
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('3D data');

# %% [markdown]
# ## saving the figures in .png images

# %%
fig.savefig('image1.png', bbox_inches='tight')

# %%
fig2 = plt.figure(figsize=(10,6))
ax2=plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();

# %% [markdown]
# # saving the figures in .png images

# %%
fig2.savefig('image2.png', bbox_inches='tight')

# %%
fig3 = plt.figure(figsize=(20,10))
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z');

# %%
ax.view_init(60, 35)
fig3

# %% [markdown]
# # saving the figures in .png images

# %%
fig3.savefig('image3.png', bbox_inches='tight')

# %%
fig4 = plt.figure(figsize=(20,10))
plt.contour(X, Y, Z, colors='black');
plt.colorbar();

# %% [markdown]
# # saving the figures in .png images

# %%
fig4.savefig('image4.png', bbox_inches='tight')

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %%
import pandas as pd

# %%
Table1=pd.DataFrame({'name':['mary','joseph'],'drink':['wine','peer']})
Table2=pd.DataFrame({'name':['peter','paul','mary'],'food':['fish','beans','bread']})

# %%
Table1
# Out:
#      name drink
# 0    mary  wine
# 1  joseph  peer

# %%
Table2
# Out:
#     name   food
# 0  peter   fish
# 1   paul  beans
# 2   mary  bread

# %% [markdown]
# # Inner Join

# %%
pd.merge(Table1,Table2,on='name',how='inner',indicator=True)
# Out:
#    name drink   food _merge
# 0  mary  wine  bread   both

# %%
pd.merge(Table1,Table2,on='name',how='outer',indicator=True)
# Out:
#      name drink   food      _merge
# 0    mary  wine  bread        both
# 1  joseph  peer    NaN   left_only
# 2   peter   NaN   fish  right_only
# 3    paul   NaN  beans  right_only
